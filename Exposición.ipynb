# %% [markdown]
# # EXPOSICIÓN

# %% [markdown]
# # QUANDL.
# ¿QUÉ ES?

# %% [markdown]
# Es una plataforma de Data Products financieros cuya característica diferenciadora son los datos no convencionales. Esta empresa es un claro ejemplo de monetización de data products y su catálogo de data products debería estar presente en cualquier iniciativa que implique el cruce de datos financieros.
#
# Esta herramienta permite visualizar y descargar (a Excel y a otros Softwares):
#
# * Precios históricos de commodities (Café, Cacao, Banano, Hule, Azúcar, etc)
# * Precios de acciones de empresas específicas (Open, High, Close, Volumen)
# * Volúmenes de transacciones de los mercados bursátiles (Nasdaq, FTSE, S&P500)
# * Datos sobre divisas(Bonos, tasas de interés, indicadores)
# * Data alternativa que explicaré con mas detalle a continuación:
#
# No todas las bases de datos son gratuitas en Quandl, existen unas de pago especialmente las denominadas «alternative data» cuyo objetivo es poder complementar las bases de datos generadas en una empresa con datos capturados afuera.
#
# En términos prácticos qué es Data Alternativa? :
#
# * Imágenes satelitales tomadas día a día
# * Datos de geoposición obtenidos de celulares
# * Datos de transacciones de los consumidores obtenidos a través de los recibos electrónicos, entre otros.

# %% [markdown]
# **Instalando Quandl**

# %%
pip install quandl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cufflinks
# Out:
# ...
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# ...
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import cufflinks as cf
import configparser as cp
import quandl
import sys

# %% [markdown]
# *Importamos los datos de la API*

# %%
IBM = quandl.get("WIKI/IBM")
GOOGLE = quandl.get("WIKI/GOOGL")
AMAZON = quandl.get("WIKI/AMZN")
MICROSOFT = quandl.get("WIKI/MSFT")

# %%
IBM
# Out:
#               Open    High    Low  Close      Volume  Ex-Dividend  \
# Date
# 1986-03-13  25.500  29.250  25.50  28.00   3582600.0          0.0
# 1986-03-14  28.000  29.500  28.00  29.00   1070000.0          0.0
# 1986-03-17  29.000  29.750  29.00  29.50    462400.0          0.0
# 1986-03-18  29.500  29.750  28.50  28.75    235300.0          0.0
# 1986-03-19  28.750  29.000  28.00  28.25    166300.0          0.0
# ...            ...     ...    ...    ...         ...          ...
# 2018-03-21  92.930  94.050  92.21  92.48  23753263.0          0.0
# 2018-03-22  91.265  91.750  89.66  89.79  37578166.0          0.0
# 2018-03-23  89.500  90.460  87.08  87.18  42159397.0          0.0
# 2018-03-26  90.610  94.000  90.40  93.78  55031149.0          0.0
# 2018-03-27  94.940  95.139  88.51  89.47  53704562.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 1986-03-13          1.0   0.058941   0.067609   0.058941    0.064720
# ...

# %%
GOOGLE
# Out:
#                Open     High      Low     Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19   100.01   104.06    95.96   100.335  44659000.0          0.0
# 2004-08-20   101.01   109.08   100.50   108.310  22834300.0          0.0
# 2004-08-23   110.76   113.48   109.05   109.400  18256100.0          0.0
# 2004-08-24   111.24   111.60   103.57   104.870  15247300.0          0.0
# 2004-08-25   104.76   108.00   103.88   106.000   9188600.0          0.0
# ...             ...      ...      ...       ...         ...          ...
# 2018-03-21  1092.57  1108.70  1087.21  1094.000   1990515.0          0.0
# 2018-03-22  1080.01  1083.92  1049.64  1053.150   3418154.0          0.0
# 2018-03-23  1051.37  1066.78  1024.87  1026.550   2413517.0          0.0
# 2018-03-26  1050.60  1059.27  1010.58  1054.090   3272409.0          0.0
# 2018-03-27  1063.90  1064.54   997.62  1006.940   2940957.0          0.0
#
#             Split Ratio    Adj. Open    Adj. High     Adj. Low   Adj. Close  \
# Date
# ...

# %%
AMAZON
# Out:
#                Open     High      Low    Close     Volume  Ex-Dividend  \
# Date
# 1997-05-16    22.38    23.75    20.50    20.75  1225000.0          0.0
# 1997-05-19    20.50    21.25    19.50    20.50   508900.0          0.0
# 1997-05-20    20.75    21.00    19.63    19.63   455600.0          0.0
# 1997-05-21    19.25    19.75    16.50    17.13  1571100.0          0.0
# 1997-05-22    17.25    17.38    15.75    16.75   981400.0          0.0
# ...             ...      ...      ...      ...        ...          ...
# 2018-03-21  1586.45  1590.00  1563.17  1581.86  4667291.0          0.0
# 2018-03-22  1565.47  1573.85  1542.40  1544.10  6177737.0          0.0
# 2018-03-23  1539.01  1549.02  1495.36  1495.56  7843966.0          0.0
# 2018-03-26  1530.00  1556.99  1499.25  1555.86  5547618.0          0.0
# 2018-03-27  1572.40  1575.96  1482.32  1497.05  6793279.0          0.0
#
#             Split Ratio    Adj. Open    Adj. High     Adj. Low   Adj. Close  \
# Date
# ...

# %%
MICROSOFT
# Out:
#               Open    High    Low  Close      Volume  Ex-Dividend  \
# Date
# 1986-03-13  25.500  29.250  25.50  28.00   3582600.0          0.0
# 1986-03-14  28.000  29.500  28.00  29.00   1070000.0          0.0
# 1986-03-17  29.000  29.750  29.00  29.50    462400.0          0.0
# 1986-03-18  29.500  29.750  28.50  28.75    235300.0          0.0
# 1986-03-19  28.750  29.000  28.00  28.25    166300.0          0.0
# ...            ...     ...    ...    ...         ...          ...
# 2018-03-21  92.930  94.050  92.21  92.48  23753263.0          0.0
# 2018-03-22  91.265  91.750  89.66  89.79  37578166.0          0.0
# 2018-03-23  89.500  90.460  87.08  87.18  42159397.0          0.0
# 2018-03-26  90.610  94.000  90.40  93.78  55031149.0          0.0
# 2018-03-27  94.940  95.139  88.51  89.47  53704562.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 1986-03-13          1.0   0.058941   0.067609   0.058941    0.064720
# ...

# %%
GOOGLE.info()   #Nos da la información del dataframe, nombre de columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3424 entries, 2004-08-19 to 2018-03-27
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         3424 non-null   float64
#  1   High         3424 non-null   float64
#  2   Low          3424 non-null   float64
#  3   Close        3424 non-null   float64
#  4   Volume       3424 non-null   float64
#  5   Ex-Dividend  3424 non-null   float64
#  6   Split Ratio  3424 non-null   float64
#  7   Adj. Open    3424 non-null   float64
#  8   Adj. High    3424 non-null   float64
#  9   Adj. Low     3424 non-null   float64
#  10  Adj. Close   3424 non-null   float64
#  11  Adj. Volume  3424 non-null   float64
# dtypes: float64(12)
# memory usage: 347.8 KB

# %%
GOOGLE.describe()    # Nos da el resumen estadístico de las varibles financieras
# Out:
#               Open         High          Low        Close        Volume  \
# count  3424.000000  3424.000000  3424.000000  3424.000000  3.424000e+03
# mean    596.602610   602.045438   590.571710   596.352862  7.818568e+06
# std     226.989782   227.783310   225.846581   226.896692  8.248211e+06
# min      99.090000   101.740000    95.960000   100.010000  5.211410e+05
# 25%     461.157500   465.392500   456.065000   461.205000  2.430647e+06
# 50%     565.120000   569.599950   559.860000   564.940000  5.076200e+06
# 75%     735.627500   740.850000   728.680025   733.262500  1.020910e+07
# max    1226.800000  1228.880000  1218.600000  1220.170000  8.215110e+07
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  3424.000000       3424.0  3424.000000  3424.000000  3424.000000
# mean      0.165880          1.0   409.221461   412.786556   405.227809
# std       9.706436          0.0   257.844081   259.366718   255.981628
# ...

# %% [markdown]
# **Graficando las variables**

# %%
pip install chart_studio
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=5b7527a1587afe4a098541d8906b32ef4160f1a7cda5ecc27f96c0aa83186e6e
#   Stored in directory: c:\users\casti\appdata\local\pip\cache\wheels\ce\18\7f\e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import chart_studio
chart_studio.tools.set_credentials_file(username='DianaCss', api_key='tjFv80duzoXkz30MiKaK')

# %%
IBM["Adj. Close"].iplot()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~DianaCss/1.embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
GOOGLE["Adj. Close"].iplot()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~DianaCss/3.embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
AMAZON["Adj. Close"].iplot()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~DianaCss/5.embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
MICROSOFT["Adj. Close"].iplot()
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~DianaCss/7.embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IBM["Adj. Close"].plot(figsize=(30,15), title='Precios de cierre', label="IBM")
GOOGLE["Adj. Close"].plot(label="GOOGLE")
AMAZON["Adj. Close"].plot(label="AMAZON")
MICROSOFT["Adj. Close"].plot(label="MICROSOFT")
# Out:
# <AxesSubplot:title={'center':'Precios de cierre'}, xlabel='Date'>

# %% [markdown]
# # EJERCICIO: obtener datos de Divisas de varios Países

# %% [markdown]
# ## Obteniendo los datos de una fecha inicial hasta la fecha final

# %%
#Importando librería pandas y quandl
import pandas as pd 
import quandl

# %%
#Importando librería matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
quandl.ApiConfig.api_key="Dn15F3nEKb9aSGgVc9qg"
quandl.get("ODA/MEX_NGDPRPC", authtoken="Dn15F3nEKb9aSGgVc9qg")
# Out:
#                 Value
# Date
# 1980-12-31  109816.31
# 1981-12-31  116440.22
# 1982-12-31  113264.57
# 1983-12-31  106967.17
# 1984-12-31  108303.41
# 1985-12-31  108412.26
# 1986-12-31  102979.81
# 1987-12-31  102712.03
# 1988-12-31  102026.56
# 1989-12-31  104167.09
# 1990-12-31  105321.71
# 1991-12-31  107821.31
# 1992-12-31  109779.42
# 1993-12-31  110977.06
# 1994-12-31  114640.00
# 1995-12-31  105796.22
# 1996-12-31  111328.70
# 1997-12-31  117326.18
# 1998-12-31  121780.18
# 1999-12-31  123601.53
# 2000-12-31  128180.95
# 2001-12-31  126129.38
# 2002-12-31  124499.57
# 2003-12-31  124730.06
# 2004-12-31  128113.39
# 2005-12-31  129602.81
# 2006-12-31  133857.25
# 2007-12-31  135205.20
# 2008-12-31  134894.08
# 2009-12-31  126005.07
# 2010-12-31  130827.73
# 2011-12-31  133946.66
# 2012-12-31  137199.57
# 2013-12-31  137481.99
# 2014-12-31  139781.20
# 2015-12-31  142834.92
# 2016-12-31  145483.92
# 2017-12-31  146998.51
# 2018-12-31  148464.15
# 2019-12-31  149451.25
# ...

# %%
dicom = quandl.get('BCB/13521', start_date='2020-12-31', end_date='2022-12-31')

# %%
codes = pd.read_csv('BCB_metadata.csv', sep=',')

# %%
codes
# Out:
#           code                                               name  \
# 0            1  Exchange rate, Free, United States dollar (sal...
# 1           10   Rio de Janeiro stock market (BVRJ), total amount
# 2          100  Credit operations with nonearmarked funds (pre...
# 3         1000  Credit operations with nonearmarked funds (flo...
# 4        10000  FDI, France, Manufacture of eletric machines, ...
# ...        ...                                                ...
# 13721     9998  FDI, France, Manufacture of machines and equip...
# 13722  UDJCAD1                        Dow Jones Composite Average
# 13723  UDJIAD1                       Dow Jones Industrial Average
# 13724  UDJTAD1                   Dow Jones Transportation Average
# 13725  UDJUAD1                          Dow Jones Utility Average
#
#                                              description         refreshed_at  \
# 0      Exchange rate, Free, United States dollar (sal...  2022-06-20 21:41:49
# ...

# %% [markdown]
# # Obtener datos

# %% [markdown]
# **Quandl** devuelve datos como una serie temporal o un marco de datos. Esto es apropiado porque usar Pandas es mi herramienta favorita para el análisis de datos. Veamos algunos ejemplos.
#
# Iniciaremos el método quandl.get, que devuelve una serie temporal.

# %%
data = quandl.get("FRED/GDP", start_date="2011-01-01", end_date="2021-12-31", returns='np')

# %%
data
# Out:
#                 Value
# Date
# 2011-01-01  15351.444
# 2011-04-01  15557.535
# 2011-07-01  15647.681
# 2011-10-01  15842.267
# 2012-01-01  16068.824
# 2012-04-01  16207.130
# 2012-07-01  16319.540
# 2012-10-01  16420.386
# 2013-01-01  16629.050
# 2013-04-01  16699.551
# 2013-07-01  16911.068
# 2013-10-01  17133.114
# 2014-01-01  17144.281
# 2014-04-01  17462.703
# 2014-07-01  17743.227
# 2014-10-01  17852.540
# 2015-01-01  17991.348
# 2015-04-01  18193.707
# 2015-07-01  18306.960
# 2015-10-01  18332.079
# 2016-01-01  18425.306
# 2016-04-01  18611.617
# 2016-07-01  18775.459
# 2016-10-01  18968.041
# 2017-01-01  19153.912
# 2017-04-01  19322.920
# 2017-07-01  19558.693
# 2017-10-01  19882.965
# 2018-01-01  20143.716
# 2018-04-01  20492.492
# 2018-07-01  20659.102
# 2018-10-01  20813.325
# 2019-01-01  21001.591
# 2019-04-01  21289.268
# 2019-07-01  21505.012
# 2019-10-01  21694.458
# 2020-01-01  21481.367
# 2020-04-01  19477.444
# 2020-07-01  21138.574
# 2020-10-01  21477.597
# ...

# %% [markdown]
# # Precios Quandl WIKI

# %% [markdown]
# Lo siguiente toma datos de la tabla **'WIKI/PRICES'** y usa el parámetro *qopts* para seleccionar las columnas deseadas, los tickers **AAPL y MSFT**, y aplica un filtro de fecha.
#
# Tenga en cuenta que, debido al gran volumen de llamadas a la API, el programa de precios de acciones gratuitos se suspendió el 11 de abril de 2018.

# %%
data = quandl.get_table('WIKI/PRICES',
                        qopts = { 'columns': ['ticker', 'date', 'close'] },
                        ticker = ['AAPL', 'MSFT'],
                        date = { 'gte': '2016-01-01', 'lte': '2016-12-31' })

# %%
data
# Out:
#      ticker       date   close
# None
# 0      MSFT 2016-12-30   62.14
# 1      MSFT 2016-12-29   62.90
# 2      MSFT 2016-12-28   62.99
# 3      MSFT 2016-12-27   63.28
# 4      MSFT 2016-12-23   63.24
# ...     ...        ...     ...
# 499    AAPL 2016-01-08   96.96
# 500    AAPL 2016-01-07   96.45
# 501    AAPL 2016-01-06  100.70
# 502    AAPL 2016-01-05  102.71
# 503    AAPL 2016-01-04  105.35
#
# [504 rows x 3 columns]
